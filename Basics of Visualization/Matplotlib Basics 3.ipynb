# %% [markdown]
# ## Importing Modules

# %%
import matplotlib as mpl
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Legends and annotation

# %%
#help(plt.legend) #print(mpl.rcParams) #help(mpl.text.Text)

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.set_yticks([])
ax.set_xticks([]) # If we remove the ticks, the numbers appear in the axes by default. 
ax.set_xlim(-0.5, 5)
ax.set_ylim(-0.1, 0.3)
ax.axhline(0) #horizontal line

#text
ax.text(-0.35, 0.25, "This is a test for matplotlib", fontsize=12, family="cursive")

#annotations
ax.plot(1, 0, 'o')
ax.annotate("Point", xy=(1, 0), xytext=(1.2, 0.1), 
            fontsize=12, family="sans-serif",
           xycoords="data", 
            arrowprops=dict(arrowstyle="-|>", connectionstyle="arc3, rad=.4"))

#equation
ax.text(2, 0.1, r"Euler's identity: $e^{i\pi}\ = -1$",
       fontsize=14, family="cursive", alpha = 0.7, fontweight="demibold")
# Out:
# Text(2, 0.1, "Euler's identity: $e^{i\\pi}\\ = -1$")

# %%
x = np.linspace(0, 50, 500)
y = np.sin(x) * np.exp(-x/10)

fig, ax = plt.subplots(figsize=(8, 4), subplot_kw={'facecolor':"beige"})

ax.plot(x, y, lw=3)

ax.set_xlabel("x", labelpad=5, fontsize=16, 
              fontname='serif', color="teal")

ax.set_ylabel("f(x)", labelpad=5, fontsize=16, 
              fontname='serif', color="teal")

ax.set_title("Axis Title", pad=15, fontsize=16, 
             fontname='serif', color="teal")
# Out:
# Text(0.5, 1.0, 'Axis Title')

# %% [markdown]
# ## X and Y ticks and range

# %%
x = np.linspace(0, 50, 500)
y = np.cos(x)/np.exp(20/x)

fig, axes = plt.subplots(1, 3, figsize=(8, 3),
                         subplot_kw={'facecolor': "beige"})

axes[0].plot(x, y, lw=2)
axes[0].set_xlim(-5, 40)
axes[0].set_ylim(-1, 1)
axes[0].set_title("set_xlim / set_ylim")

axes[1].plot(x, y, lw=2)
axes[1].axis('tight')
axes[1].set_title("axis('tight')")

axes[2].plot(x, y, lw=2)
axes[2].axis('equal')
axes[2].set_title("axis('equal')")
# Out:
# C:\Users\10\AppData\Local\Temp/ipykernel_8492/344641575.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   y = np.cos(x)/np.exp(20/x)
# Text(0.5, 1.0, "axis('equal')")

# %%
#mpl.ticker #mpl.ticker.MaxNLocator #mpl.ticker.FixedLocator #set_major_locator #set_minor_locator
#Axes.xaxis, Axes.yaxis #set_xticks, set_yticks -> major #set_xticklabels, t_yticklabels

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)
y = np.cos(x + np.cos(x)) * np.exp(-x**2/25)

fig, axes = plt.subplots(1, 4, figsize=(12, 3))

axes[0].plot(x, y, lw=2)
axes[0].set_title("default ticks")

axes[1].plot(x, y, lw=2)
axes[1].set_title("set_xticks")
axes[1].set_yticks([-1, 0, 1])
axes[1].set_xticks([-5, 0, 5])

axes[2].plot(x, y, lw=2)
axes[2].set_title("set_major_locator")
axes[2].xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
axes[2].yaxis.set_major_locator(mpl.ticker.FixedLocator([-1, 0, 1]))
axes[2].xaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))
axes[2].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))

axes[3].plot(x, y, lw=2)
axes[3].set_title("set_xticklabels")
axes[3].set_yticks([-1, 0, 1])
axes[3].set_xticks([-2 * np.pi, -np.pi, 0, np.pi, 2 * np.pi])
axes[3].set_xticklabels([r'$-2\pi$', r'$-\pi$', 0, r'$\pi$', r'$2\pi$'])
x_minor_ticker = mpl.ticker.FixedLocator([-3 * np.pi / 2, -np.pi / 2, 0,
                                         np.pi / 2, 3 * np.pi / 2])
axes[3].xaxis.set_minor_locator(x_minor_ticker)
axes[3].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(4))

# %% [markdown]
# ## Installing gridlines

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

x_major_ticker = mpl.ticker.MultipleLocator(4)
x_minor_ticker = mpl.ticker.MultipleLocator(1)
y_major_ticker = mpl.ticker.MultipleLocator(0.5)
y_minor_ticker = mpl.ticker.MultipleLocator(0.25)

for ax in axes:
    ax.plot(x, y, lw=2)
    ax.xaxis.set_major_locator(x_major_ticker)
    ax.yaxis.set_major_locator(y_major_ticker)
    ax.xaxis.set_minor_locator(x_minor_ticker)
    ax.yaxis.set_minor_locator(y_minor_ticker)
    
axes[0].set_title("default grid")
axes[0].grid()

axes[1].set_title("major/minor grid")
axes[1].grid(color="blue", which="both", linestyle=":", linewidth=0.5)

axes[2].set_title("individual x/y major/minor grid")
axes[2].grid(color="grey", which="major", axis='x', linestyle='-',
            linewidth=0.5)
axes[2].grid(color="grey", which="minor", axis='x', linestyle=':',
            linewidth=0.25)
axes[2].grid(color="grey", which="major", axis='y', linestyle='--',
            linewidth=0.5)

# %% [markdown]
# ## Scientific notation

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))

x = np.linspace(0, 1e5, 200)
y = x ** 3  

axes[0].plot(x, y, 'b')
axes[0].set_title("default labels", loc='center')

axes[1].plot(x, y, 'b')
axes[1].set_title("scientific notation labels", loc='center')

formatter = mpl.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1, 1))
axes[1].xaxis.set_major_formatter(formatter)
axes[1].yaxis.set_major_formatter(formatter)
